# %% [markdown]
# <a href="https://colab.research.google.com/github/ZachPetroff/multiclass-classification/blob/main/multi_class_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv('../input/ghouls-goblins-and-ghosts-boo/train.csv.zip', compression='zip')
test_df = pd.read_csv('../input/ghouls-goblins-and-ghosts-boo/test.csv.zip', compression='zip')

train_df.head()
# Out:
#    id  bone_length  rotting_flesh  hair_length  has_soul  color    type
# 0   0     0.354512       0.350839     0.465761  0.781142  clear   Ghoul
# 1   1     0.575560       0.425868     0.531401  0.439899  green  Goblin
# 2   2     0.467875       0.354330     0.811616  0.791225  black   Ghoul
# 3   4     0.776652       0.508723     0.636766  0.884464  black   Ghoul
# 4   5     0.566117       0.875862     0.418594  0.636438  green   Ghost

# %%
cols = train_df.columns

for col in cols:
    print('Number Missing in ', col, ' column: ', sum(train_df[col].isnull()))

train_df.describe()
# Out:
# Number Missing in  id  column:  0
# Number Missing in  bone_length  column:  0
# Number Missing in  rotting_flesh  column:  0
# Number Missing in  hair_length  column:  0
# Number Missing in  has_soul  column:  0
# Number Missing in  color  column:  0
# Number Missing in  type  column:  0
#                id  bone_length  rotting_flesh  hair_length    has_soul
# count  371.000000   371.000000     371.000000   371.000000  371.000000
# mean   443.676550     0.434160       0.506848     0.529114    0.471392
# std    263.222489     0.132833       0.146358     0.169902    0.176129
# min      0.000000     0.061032       0.095687     0.134600    0.009402
# 25%    205.500000     0.340006       0.414812     0.407428    0.348002
# 50%    458.000000     0.434891       0.501552     0.538642    0.466372
# 75%    678.500000     0.517223       0.603977     0.647244    0.600610
# max    897.000000     0.817001       0.932466     1.000000    0.935721

# %% [markdown]
# # Data Preprocessing
# * Not much preprocessing to do.
# * The continuous values seem to already be between zero and one.
# * There are no missing values, so no imputation or row deletion is necessary.
# * However, the color and type columns need to be one-hot encoded.
# * Because type is the target value, I am going to take a different approach. First I will use pandas to get the dummy values, then I am going to transfer this to a numpy array. This array will be used in training

# %%
color = pd.get_dummies(train_df['color'], prefix='color')

train_df = train_df.drop(['color'], axis=1)
train_df = pd.concat([train_df, color], axis=1)

# %%
target_df = pd.get_dummies(train_df['type'])
target = target_df.to_numpy()

train_df = train_df.drop(['type'], axis=1)
target_df.head()
# Out:
#    Ghost  Ghoul  Goblin
# 0      0      1       0
# 1      0      0       1
# 2      0      1       0
# 3      0      1       0
# 4      1      0       0

# %% [markdown]
# # Model Building
# > Usually, I would use a random forest classifier to see if any unimportant columns can be dropped. However, there is very little data, so I am going to skip this step. Hopefully, because there is a low amount of data, many models can be tested in a very short time.
#
# **Models:**
# * SVC - My prediction for the best model, works well with low data
# * Nearest Neighbors - Also is usually pretty good
# * Random Forest
# * If nothing else works, I will try a simple feed-forward NN.

# %%
x = train_df.to_numpy()

# %% [markdown]
# I did not realize sklearn does not like when the target is not a one dimensional array. Below, I use the original target array to create a one-d array.

# %%
y = []

for v in target:
    y.append(list(v).index(1))
    
y = np.array(y)

# %%
from sklearn import svm, neighbors
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

svc = svm.SVC()
nn = neighbors.KNeighborsClassifier(10)
forest = RandomForestClassifier(max_depth=2, random_state=0)

models = [svc, nn, forest]
names = ['SVC', 'Nearest Neighbors', 'Random Forest']

for model in range(len(models)):
    cv_results = cross_val_score(models[model], x, y, cv=2)
    print(names[model], ": ", cv_results.mean())
# Out:
# SVC :  0.3396396396396396
# Nearest Neighbors :  0.34234234234234234
# Random Forest :  0.7061319383900029

# %% [markdown]
# It seems Random Forest heavily outperforms the other two models. I will fine tune below.

# %%
n_ests = [50, 100, 250, 500]
depths = [1, 2, 3]
crits = ['gini', 'entropy']

for est in n_ests:
    for d in depths:
        for crit in crits:
            forest = RandomForestClassifier(max_depth=d, n_estimators=est, criterion=crit, random_state=0)
            cv_results = cross_val_score(forest, x, y, cv=3)
            print("Estimators: ", est, " Depth: ", d, " Criterion: ", crit, " Score: ", cv_results.mean())
# Out:
# Estimators:  50  Depth:  1  Criterion:  gini  Score:  0.6442215228603899
# Estimators:  50  Depth:  1  Criterion:  entropy  Score:  0.6496415770609318
# Estimators:  50  Depth:  2  Criterion:  gini  Score:  0.6657924643762566
# Estimators:  50  Depth:  2  Criterion:  entropy  Score:  0.6576405280181834
# Estimators:  50  Depth:  3  Criterion:  gini  Score:  0.6818996415770608
# Estimators:  50  Depth:  3  Criterion:  entropy  Score:  0.6765232974910393
# Estimators:  100  Depth:  1  Criterion:  gini  Score:  0.6577060931899642
# Estimators:  100  Depth:  1  Criterion:  entropy  Score:  0.655061631261474
# Estimators:  100  Depth:  2  Criterion:  gini  Score:  0.6765888626628201
# Estimators:  100  Depth:  2  Criterion:  entropy  Score:  0.6685024914765276
# Estimators:  100  Depth:  3  Criterion:  gini  Score:  0.6791896144767899
# Estimators:  100  Depth:  3  Criterion:  entropy  Score:  0.6711469534050178
# Estimators:  250  Depth:  1  Criterion:  gini  Score:  0.6469315499606609
# Estimators:  250  Depth:  1  Criterion:  entropy  Score:  0.6442433779176501
# Estimators:  250  Depth:  2  Criterion:  gini  Score:  0.6712562286913192
# Estimators:  250  Depth:  2  Criterion:  entropy  Score:  0.6658361744907771
# Estimators:  250  Depth:  3  Criterion:  gini  Score:  0.6818777865198008
# Estimators:  250  Depth:  3  Criterion:  entropy  Score:  0.6738132703907684
# Estimators:  500  Depth:  1  Criterion:  gini  Score:  0.6388014686598479
# Estimators:  500  Depth:  1  Criterion:  entropy  Score:  0.6361132966168371
# Estimators:  500  Depth:  2  Criterion:  gini  Score:  0.6604379753474955
# Estimators:  500  Depth:  2  Criterion:  entropy  Score:  0.6631698575050267
# Estimators:  500  Depth:  3  Criterion:  gini  Score:  0.6765014424337793
# Estimators:  500  Depth:  3  Criterion:  entropy  Score:  0.6791896144767899

# %% [markdown]
# Because two of the best scores have a max depth of 3, I will expand the search for depth.

# %%
depths = [3, 4, 5, 6]

for d in depths:
    forest = RandomForestClassifier(max_depth=d, n_estimators=50, random_state=0)
    cv_results = cross_val_score(forest, x, y, cv=3)
    print("Depth: ", d, " Score: ", cv_results.mean())
# Out:
# Depth:  3  Score:  0.6818996415770608
# Depth:  4  Score:  0.7061806101931988
# Depth:  5  Score:  0.6952530815630737
# Depth:  6  Score:  0.6790147740187079

# %% [markdown]
# These params seem to give us the best score:
# * N_Estimators: 50
# * Max Depth: 4
# * Criterion: Gini
#
# validation score = 70.62

# %% [markdown]
# This score is good, however, a neural network would likely do better. I will use pytorch to build and train a model.

# %%
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable

# %%
class Net(nn.Module):
    def __init__(self, ):
        super(Net, self).__init__()
        # basic feed forward NN architecture
        self.fc1 = nn.Linear(11, 20)
        self.fc2 = nn.Linear(20, 30)
        self.fc3 = nn.Linear(30, 20)
        self.fc4 = nn.Linear(20, 3)
        self.activation = nn.ReLU()
        self.output = nn.Softmax()
    def forward(self, x):
        x = self.activation(self.fc1(x))
        x = self.activation(self.fc2(x))
        x = self.activation(self.fc3(x))
        x = self.output(self.fc4(x))
        return x
ann = Net()
# loss fxn
crit = nn.MSELoss()
# hyperparameters
opt = optim.Adam(ann.parameters(), lr = 5e-4)

# %% [markdown]
# Split for training and testing

# %%
import random

x_train = []
x_test = []
y_train = []
y_test = []

for i in range(len(x)):
    if random.random() > .1:
        x_train.append(x[i])
        y_train.append(target[i])
    else:
        x_test.append(x[i])
        y_test.append(target[i])

x_train = np.array(x_train)
x_test = np.array(x_test)

train_x = torch.FloatTensor(x_train)
test_x = torch.FloatTensor(x_test)

train_y = torch.FloatTensor(y_train)
test_y = torch.FloatTensor(y_test)

# %%
nb_epoch = 200
for epoch in range(1, nb_epoch + 1):
  train_loss = 0
  s = 0.
  for index in range(len(train_x)):
    opt.zero_grad()
    
    # get input
    inp = Variable(train_x[index]).unsqueeze(0)

    # expected output is the same as input, so we clone input
    targ = train_y[index]
    
    # get output from nn
    output = ann(inp)

    # target will not be changed
    targ.require_grad = False
    
    # get loss (difference between output and original input)
    loss = crit(output, targ)
    
    # propagate loss backward in the network
    loss.backward()
    
    # update train loss
    train_loss += np.sqrt(loss.data)
    s += 1.
    opt.step()
  print('epoch: '+str(epoch)+' loss: '+ str(train_loss/s))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/loss.py:528: UserWarning: Using a target size (torch.Size([3])) that is different to the input size (torch.Size([1, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# epoch: 1 loss: tensor(0.4797)
# epoch: 2 loss: tensor(0.4772)
# epoch: 3 loss: tensor(0.4768)
# epoch: 4 loss: tensor(0.4759)
# epoch: 5 loss: tensor(0.4758)
# epoch: 6 loss: tensor(0.4747)
# epoch: 7 loss: tensor(0.4744)
# epoch: 8 loss: tensor(0.4746)
# epoch: 9 loss: tensor(0.4740)
# epoch: 10 loss: tensor(0.4735)
# epoch: 11 loss: tensor(0.4731)
# epoch: 12 loss: tensor(0.4730)
# epoch: 13 loss: tensor(0.4725)
# epoch: 14 loss: tensor(0.4725)
# epoch: 15 loss: tensor(0.4713)
# epoch: 16 loss: tensor(0.4710)
# epoch: 17 loss: tensor(0.4712)
# epoch: 18 loss: tensor(0.4703)
# epoch: 19 loss: tensor(0.4702)
# epoch: 20 loss: tensor(0.4699)
# epoch: 21 loss: tensor(0.4698)
# epoch: 22 loss: tensor(0.4697)
# epoch: 23 loss: tensor(0.4693)
# epoch: 24 loss: tensor(0.4697)
# epoch: 25 loss: tensor(0.4689)
# epoch: 26 loss: tensor(0.4691)
# epoch: 27 loss: tensor(0.4683)
# epoch: 28 loss: tensor(0.4686)
# epoch: 29 loss: tensor(0.4676)
# epoch: 30 loss: tensor(0.4674)
# epoch: 31 loss: tensor(0.4671)
# epoch: 32 loss: tensor(0.4666)
# epoch: 33 loss: tensor(0.4674)
# epoch: 34 loss: tensor(0.4664)
# epoch: 35 loss: tensor(0.4663)
# epoch: 36 loss: tensor(0.4654)
# epoch: 37 loss: tensor(0.4666)
# epoch: 38 loss: tensor(0.4665)
# epoch: 39 loss: tensor(0.4656)
# epoch: 40 loss: tensor(0.4660)
# epoch: 41 loss: tensor(0.4641)
# epoch: 42 loss: tensor(0.4638)
# epoch: 43 loss: tensor(0.4638)
# epoch: 44 loss: tensor(0.4623)
# epoch: 45 loss: tensor(0.4627)
# epoch: 46 loss: tensor(0.4624)
# epoch: 47 loss: tensor(0.4624)
# epoch: 48 loss: tensor(0.4622)
# epoch: 49 loss: tensor(0.4618)
# epoch: 50 loss: tensor(0.4594)
# epoch: 51 loss: tensor(0.4589)
# epoch: 52 loss: tensor(0.4601)
# epoch: 53 loss: tensor(0.4623)
# epoch: 54 loss: tensor(0.4572)
# epoch: 55 loss: tensor(0.4585)
# epoch: 56 loss: tensor(0.4579)
# epoch: 57 loss: tensor(0.4546)
# epoch: 58 loss: tensor(0.4637)
# epoch: 59 loss: tensor(0.4553)
# epoch: 60 loss: tensor(0.4551)
# epoch: 61 loss: tensor(0.4593)
# epoch: 62 loss: tensor(0.4652)
# epoch: 63 loss: tensor(0.4705)
# epoch: 64 loss: tensor(0.4535)
# epoch: 65 loss: tensor(0.4573)
# epoch: 66 loss: tensor(0.4551)
# epoch: 67 loss: tensor(0.4588)
# epoch: 68 loss: tensor(0.4566)
# epoch: 69 loss: tensor(0.4548)
# epoch: 70 loss: tensor(0.4548)
# epoch: 71 loss: tensor(0.4497)
# epoch: 72 loss: tensor(0.4551)
# epoch: 73 loss: tensor(0.4503)
# epoch: 74 loss: tensor(0.4508)
# epoch: 75 loss: tensor(0.4501)
# epoch: 76 loss: tensor(0.4520)
# epoch: 77 loss: tensor(0.4481)
# epoch: 78 loss: tensor(0.4452)
# epoch: 79 loss: tensor(0.4491)
# epoch: 80 loss: tensor(0.4439)
# epoch: 81 loss: tensor(0.4467)
# epoch: 82 loss: tensor(0.4418)
# epoch: 83 loss: tensor(0.4423)
# epoch: 84 loss: tensor(0.4449)
# epoch: 85 loss: tensor(0.4450)
# epoch: 86 loss: tensor(0.4398)
# epoch: 87 loss: tensor(0.4418)
# epoch: 88 loss: tensor(0.4387)
# epoch: 89 loss: tensor(0.4415)
# epoch: 90 loss: tensor(0.4363)
# epoch: 91 loss: tensor(0.4387)
# epoch: 92 loss: tensor(0.4400)
# epoch: 93 loss: tensor(0.4364)
# epoch: 94 loss: tensor(0.4311)
# epoch: 95 loss: tensor(0.4341)
# epoch: 96 loss: tensor(0.4333)
# epoch: 97 loss: tensor(0.4333)
# epoch: 98 loss: tensor(0.4330)
# epoch: 99 loss: tensor(0.4318)
# epoch: 100 loss: tensor(0.4258)
# epoch: 101 loss: tensor(0.4296)
# epoch: 102 loss: tensor(0.4121)
# epoch: 103 loss: tensor(0.4121)
# epoch: 104 loss: tensor(0.4242)
# epoch: 105 loss: tensor(0.4269)
# epoch: 106 loss: tensor(0.4177)
# epoch: 107 loss: tensor(0.4188)
# epoch: 108 loss: tensor(0.4175)
# epoch: 109 loss: tensor(0.4185)
# epoch: 110 loss: tensor(0.4207)
# epoch: 111 loss: tensor(0.4147)
# epoch: 112 loss: tensor(0.4088)
# epoch: 113 loss: tensor(0.4182)
# epoch: 114 loss: tensor(0.4433)
# epoch: 115 loss: tensor(0.3917)
# epoch: 116 loss: tensor(0.4067)
# epoch: 117 loss: tensor(0.3971)
# epoch: 118 loss: tensor(0.4080)
# epoch: 119 loss: tensor(0.4042)
# epoch: 120 loss: tensor(0.4062)
# epoch: 121 loss: tensor(0.4007)
# epoch: 122 loss: tensor(0.4058)
# epoch: 123 loss: tensor(0.4042)
# epoch: 124 loss: tensor(0.4054)
# epoch: 125 loss: tensor(0.4058)
# epoch: 126 loss: tensor(0.3943)
# epoch: 127 loss: tensor(0.3980)
# epoch: 128 loss: tensor(0.3976)
# epoch: 129 loss: tensor(0.4024)
# epoch: 130 loss: tensor(0.3917)
# epoch: 131 loss: tensor(0.3975)
# epoch: 132 loss: tensor(0.3904)
# epoch: 133 loss: tensor(0.3854)
# epoch: 134 loss: tensor(0.4010)
# epoch: 135 loss: tensor(0.3739)
# epoch: 136 loss: tensor(0.3681)
# epoch: 137 loss: tensor(0.3799)
# epoch: 138 loss: tensor(0.3892)
# epoch: 139 loss: tensor(0.3830)
# epoch: 140 loss: tensor(0.3913)
# epoch: 141 loss: tensor(0.3694)
# epoch: 142 loss: tensor(0.3898)
# epoch: 143 loss: tensor(0.3783)
# epoch: 144 loss: tensor(0.3800)
# epoch: 145 loss: tensor(0.3826)
# epoch: 146 loss: tensor(0.3773)
# epoch: 147 loss: tensor(0.3907)
# epoch: 148 loss: tensor(0.3704)
# epoch: 149 loss: tensor(0.3697)
# epoch: 150 loss: tensor(0.3667)
# epoch: 151 loss: tensor(0.3746)
# epoch: 152 loss: tensor(0.3690)
# epoch: 153 loss: tensor(0.3612)
# epoch: 154 loss: tensor(0.3686)
# epoch: 155 loss: tensor(0.3504)
# epoch: 156 loss: tensor(0.3392)
# epoch: 157 loss: tensor(0.3397)
# epoch: 158 loss: tensor(0.3336)
# epoch: 159 loss: tensor(0.3537)
# epoch: 160 loss: tensor(0.3567)
# epoch: 161 loss: tensor(0.3479)
# epoch: 162 loss: tensor(0.3464)
# epoch: 163 loss: tensor(0.3353)
# epoch: 164 loss: tensor(0.3406)
# epoch: 165 loss: tensor(0.3307)
# epoch: 166 loss: tensor(0.3443)
# epoch: 167 loss: tensor(0.3288)
# epoch: 168 loss: tensor(0.3357)
# epoch: 169 loss: tensor(0.3576)
# epoch: 170 loss: tensor(0.3389)
# epoch: 171 loss: tensor(0.3370)
# epoch: 172 loss: tensor(0.3298)
# epoch: 173 loss: tensor(0.3299)
# epoch: 174 loss: tensor(0.3189)
# epoch: 175 loss: tensor(0.3257)
# epoch: 176 loss: tensor(0.3222)
# epoch: 177 loss: tensor(0.3171)
# epoch: 178 loss: tensor(0.3112)
# epoch: 179 loss: tensor(0.3129)
# epoch: 180 loss: tensor(0.3139)
# epoch: 181 loss: tensor(0.3106)
# epoch: 182 loss: tensor(0.3256)
# epoch: 183 loss: tensor(0.3073)
# epoch: 184 loss: tensor(0.3094)
# epoch: 185 loss: tensor(0.3179)
# epoch: 186 loss: tensor(0.3270)
# epoch: 187 loss: tensor(0.3127)
# epoch: 188 loss: tensor(0.3380)
# epoch: 189 loss: tensor(0.3237)
# epoch: 190 loss: tensor(0.3283)
# epoch: 191 loss: tensor(0.3118)
# epoch: 192 loss: tensor(0.3124)
# epoch: 193 loss: tensor(0.3157)
# epoch: 194 loss: tensor(0.3113)
# epoch: 195 loss: tensor(0.3113)
# epoch: 196 loss: tensor(0.3242)
# epoch: 197 loss: tensor(0.3154)
# epoch: 198 loss: tensor(0.3104)
# epoch: 199 loss: tensor(0.3084)
# epoch: 200 loss: tensor(0.3120)

# %%
def score(data, targ):
  acc = 0
  for i in range(len(data)):
    with torch.no_grad():
      input = Variable(data[i]).unsqueeze(0)
      target = targ[i]
    
      # get output from nn
      output = ann(input)

      if list(target).index(1) == list(output[0]).index(max(list(output[0]))):
        acc += 1

  return(acc/len(data))

print(score(test_x, test_y))
# Out:
# 0.4864864864864865
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app

# %% [markdown]
# Pretty good score, better than anything else. I attempt to build a better model below, without deleting the original model

# %%
class Net(nn.Module):
    def __init__(self, ):
        super(Net, self).__init__()
        # basic feed forward NN architecture
        self.fc1 = nn.Linear(11, 12)
        self.fc2 = nn.Linear(12, 24)
        self.fc3 = nn.Linear(24, 12)
        self.fc4 = nn.Linear(12, 3)
        self.activation = nn.ReLU()
        self.output = nn.Softmax()
    def forward(self, x):
        x = self.activation(self.fc1(x))
        x = self.activation(self.fc2(x))
        x = self.activation(self.fc3(x))
        x = self.output(self.fc4(x))
        return x
ann2 = Net()
# loss fxn
crit = nn.MSELoss()
# hyperparameters
opt = optim.Adam(ann2.parameters(), lr = 1e-3)

# %%
nb_epoch = 300
for epoch in range(1, nb_epoch + 1):
  train_loss = 0
  s = 0.
  for index in range(len(train_x)):
    opt.zero_grad()
    
    # get input
    inp = Variable(train_x[index]).unsqueeze(0)

    # expected output is the same as input, so we clone input
    targ = train_y[index]
    
    # get output from nn
    output = ann2(inp)

    # target will not be changed
    targ.require_grad = False
    
    # get loss (difference between output and original input)
    loss = crit(output, targ)
    
    # propagate loss backward in the network
    loss.backward()
    
    # update train loss
    train_loss += np.sqrt(loss.data)
    s += 1.
    opt.step()
  print('epoch: '+str(epoch)+' loss: '+ str(train_loss/s))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# epoch: 1 loss: tensor(0.4781)
# epoch: 2 loss: tensor(0.4759)
# epoch: 3 loss: tensor(0.4748)
# epoch: 4 loss: tensor(0.4738)
# epoch: 5 loss: tensor(0.4731)
# epoch: 6 loss: tensor(0.4733)
# epoch: 7 loss: tensor(0.4720)
# epoch: 8 loss: tensor(0.4721)
# epoch: 9 loss: tensor(0.4723)
# epoch: 10 loss: tensor(0.4712)
# epoch: 11 loss: tensor(0.4711)
# epoch: 12 loss: tensor(0.4710)
# epoch: 13 loss: tensor(0.4709)
# epoch: 14 loss: tensor(0.4715)
# epoch: 15 loss: tensor(0.4731)
# epoch: 16 loss: tensor(0.4710)
# epoch: 17 loss: tensor(0.4712)
# epoch: 18 loss: tensor(0.4709)
# epoch: 19 loss: tensor(0.4708)
# epoch: 20 loss: tensor(0.4707)
# epoch: 21 loss: tensor(0.4704)
# epoch: 22 loss: tensor(0.4703)
# epoch: 23 loss: tensor(0.4704)
# epoch: 24 loss: tensor(0.4702)
# epoch: 25 loss: tensor(0.4700)
# epoch: 26 loss: tensor(0.4700)
# epoch: 27 loss: tensor(0.4700)
# epoch: 28 loss: tensor(0.4698)
# epoch: 29 loss: tensor(0.4699)
# epoch: 30 loss: tensor(0.4696)
# epoch: 31 loss: tensor(0.4696)
# epoch: 32 loss: tensor(0.4694)
# epoch: 33 loss: tensor(0.4694)
# epoch: 34 loss: tensor(0.4708)
# epoch: 35 loss: tensor(0.4694)
# epoch: 36 loss: tensor(0.4692)
# epoch: 37 loss: tensor(0.4691)
# epoch: 38 loss: tensor(0.4697)
# epoch: 39 loss: tensor(0.4694)
# epoch: 40 loss: tensor(0.4690)
# epoch: 41 loss: tensor(0.4689)
# epoch: 42 loss: tensor(0.4686)
# epoch: 43 loss: tensor(0.4686)
# epoch: 44 loss: tensor(0.4687)
# epoch: 45 loss: tensor(0.4683)
# epoch: 46 loss: tensor(0.4683)
# epoch: 47 loss: tensor(0.4680)
# epoch: 48 loss: tensor(0.4678)
# epoch: 49 loss: tensor(0.4682)
# epoch: 50 loss: tensor(0.4676)
# epoch: 51 loss: tensor(0.4677)
# epoch: 52 loss: tensor(0.4672)
# epoch: 53 loss: tensor(0.4680)
# epoch: 54 loss: tensor(0.4670)
# epoch: 55 loss: tensor(0.4670)
# epoch: 56 loss: tensor(0.4672)
# epoch: 57 loss: tensor(0.4668)
# epoch: 58 loss: tensor(0.4670)
# epoch: 59 loss: tensor(0.4665)
# epoch: 60 loss: tensor(0.4657)
# epoch: 61 loss: tensor(0.4672)
# epoch: 62 loss: tensor(0.4667)
# epoch: 63 loss: tensor(0.4663)
# epoch: 64 loss: tensor(0.4659)
# epoch: 65 loss: tensor(0.4662)
# epoch: 66 loss: tensor(0.4655)
# epoch: 67 loss: tensor(0.4660)
# epoch: 68 loss: tensor(0.4655)
# epoch: 69 loss: tensor(0.4661)
# epoch: 70 loss: tensor(0.4658)
# epoch: 71 loss: tensor(0.4659)
# epoch: 72 loss: tensor(0.4653)
# epoch: 73 loss: tensor(0.4672)
# epoch: 74 loss: tensor(0.4648)
# epoch: 75 loss: tensor(0.4644)
# epoch: 76 loss: tensor(0.4628)
# epoch: 77 loss: tensor(0.4647)
# epoch: 78 loss: tensor(0.4643)
# epoch: 79 loss: tensor(0.4666)
# epoch: 80 loss: tensor(0.4653)
# epoch: 81 loss: tensor(0.4649)
# epoch: 82 loss: tensor(0.4641)
# epoch: 83 loss: tensor(0.4637)
# epoch: 84 loss: tensor(0.4634)
# epoch: 85 loss: tensor(0.4651)
# epoch: 86 loss: tensor(0.4638)
# epoch: 87 loss: tensor(0.4633)
# epoch: 88 loss: tensor(0.4620)
# epoch: 89 loss: tensor(0.4622)
# epoch: 90 loss: tensor(0.4621)
# epoch: 91 loss: tensor(0.4653)
# epoch: 92 loss: tensor(0.4614)
# epoch: 93 loss: tensor(0.4625)
# epoch: 94 loss: tensor(0.4607)
# epoch: 95 loss: tensor(0.4613)
# epoch: 96 loss: tensor(0.4606)
# epoch: 97 loss: tensor(0.4643)
# epoch: 98 loss: tensor(0.4636)
# epoch: 99 loss: tensor(0.4623)
# epoch: 100 loss: tensor(0.4620)
# epoch: 101 loss: tensor(0.4617)
# epoch: 102 loss: tensor(0.4622)
# epoch: 103 loss: tensor(0.4603)
# epoch: 104 loss: tensor(0.4630)
# epoch: 105 loss: tensor(0.4595)
# epoch: 106 loss: tensor(0.4610)
# epoch: 107 loss: tensor(0.4613)
# epoch: 108 loss: tensor(0.4589)
# epoch: 109 loss: tensor(0.4599)
# epoch: 110 loss: tensor(0.4597)
# epoch: 111 loss: tensor(0.4608)
# epoch: 112 loss: tensor(0.4605)
# epoch: 113 loss: tensor(0.4589)
# epoch: 114 loss: tensor(0.4593)
# epoch: 115 loss: tensor(0.4598)
# epoch: 116 loss: tensor(0.4603)
# epoch: 117 loss: tensor(0.4592)
# epoch: 118 loss: tensor(0.4578)
# epoch: 119 loss: tensor(0.4584)
# epoch: 120 loss: tensor(0.4592)
# epoch: 121 loss: tensor(0.4579)
# epoch: 122 loss: tensor(0.4576)
# epoch: 123 loss: tensor(0.4576)
# epoch: 124 loss: tensor(0.4579)
# epoch: 125 loss: tensor(0.4573)
# epoch: 126 loss: tensor(0.4575)
# epoch: 127 loss: tensor(0.4580)
# epoch: 128 loss: tensor(0.4586)
# epoch: 129 loss: tensor(0.4610)
# epoch: 130 loss: tensor(0.4583)
# epoch: 131 loss: tensor(0.4570)
# epoch: 132 loss: tensor(0.4574)
# epoch: 133 loss: tensor(0.4566)
# epoch: 134 loss: tensor(0.4561)
# epoch: 135 loss: tensor(0.4559)
# epoch: 136 loss: tensor(0.4584)
# epoch: 137 loss: tensor(0.4559)
# epoch: 138 loss: tensor(0.4563)
# epoch: 139 loss: tensor(0.4561)
# epoch: 140 loss: tensor(0.4559)
# epoch: 141 loss: tensor(0.4564)
# epoch: 142 loss: tensor(0.4558)
# epoch: 143 loss: tensor(0.4554)
# epoch: 144 loss: tensor(0.4550)
# epoch: 145 loss: tensor(0.4555)
# epoch: 146 loss: tensor(0.4553)
# epoch: 147 loss: tensor(0.4550)
# epoch: 148 loss: tensor(0.4550)
# epoch: 149 loss: tensor(0.4547)
# epoch: 150 loss: tensor(0.4550)
# epoch: 151 loss: tensor(0.4549)
# epoch: 152 loss: tensor(0.4545)
# epoch: 153 loss: tensor(0.4546)
# epoch: 154 loss: tensor(0.4555)
# epoch: 155 loss: tensor(0.4554)
# epoch: 156 loss: tensor(0.4545)
# epoch: 157 loss: tensor(0.4542)
# epoch: 158 loss: tensor(0.4546)
# epoch: 159 loss: tensor(0.4549)
# epoch: 160 loss: tensor(0.4539)
# epoch: 161 loss: tensor(0.4542)
# epoch: 162 loss: tensor(0.4548)
# epoch: 163 loss: tensor(0.4550)
# epoch: 164 loss: tensor(0.4536)
# epoch: 165 loss: tensor(0.4526)
# epoch: 166 loss: tensor(0.4525)
# epoch: 167 loss: tensor(0.4528)
# epoch: 168 loss: tensor(0.4532)
# epoch: 169 loss: tensor(0.4539)
# epoch: 170 loss: tensor(0.4538)
# epoch: 171 loss: tensor(0.4523)
# epoch: 172 loss: tensor(0.4523)
# epoch: 173 loss: tensor(0.4530)
# epoch: 174 loss: tensor(0.4519)
# epoch: 175 loss: tensor(0.4523)
# epoch: 176 loss: tensor(0.4514)
# epoch: 177 loss: tensor(0.4517)
# epoch: 178 loss: tensor(0.4507)
# epoch: 179 loss: tensor(0.4511)
# epoch: 180 loss: tensor(0.4518)
# epoch: 181 loss: tensor(0.4524)
# epoch: 182 loss: tensor(0.4513)
# epoch: 183 loss: tensor(0.4501)
# epoch: 184 loss: tensor(0.4499)
# epoch: 185 loss: tensor(0.4530)
# epoch: 186 loss: tensor(0.4487)
# epoch: 187 loss: tensor(0.4494)
# epoch: 188 loss: tensor(0.4512)
# epoch: 189 loss: tensor(0.4481)
# epoch: 190 loss: tensor(0.4492)
# epoch: 191 loss: tensor(0.4495)
# epoch: 192 loss: tensor(0.4511)
# epoch: 193 loss: tensor(0.4493)
# epoch: 194 loss: tensor(0.4473)
# epoch: 195 loss: tensor(0.4473)
# epoch: 196 loss: tensor(0.4473)
# epoch: 197 loss: tensor(0.4463)
# epoch: 198 loss: tensor(0.4477)
# epoch: 199 loss: tensor(0.4478)
# epoch: 200 loss: tensor(0.4450)
# epoch: 201 loss: tensor(0.4471)
# epoch: 202 loss: tensor(0.4489)
# epoch: 203 loss: tensor(0.4481)
# epoch: 204 loss: tensor(0.4469)
# epoch: 205 loss: tensor(0.4455)
# epoch: 206 loss: tensor(0.4466)
# epoch: 207 loss: tensor(0.4462)
# epoch: 208 loss: tensor(0.4456)
# epoch: 209 loss: tensor(0.4448)
# epoch: 210 loss: tensor(0.4445)
# epoch: 211 loss: tensor(0.4447)
# epoch: 212 loss: tensor(0.4454)
# epoch: 213 loss: tensor(0.4441)
# epoch: 214 loss: tensor(0.4432)
# epoch: 215 loss: tensor(0.4459)
# epoch: 216 loss: tensor(0.4448)
# epoch: 217 loss: tensor(0.4486)
# epoch: 218 loss: tensor(0.4448)
# epoch: 219 loss: tensor(0.4445)
# epoch: 220 loss: tensor(0.4444)
# epoch: 221 loss: tensor(0.4441)
# epoch: 222 loss: tensor(0.4429)
# epoch: 223 loss: tensor(0.4434)
# epoch: 224 loss: tensor(0.4434)
# epoch: 225 loss: tensor(0.4435)
# epoch: 226 loss: tensor(0.4455)
# epoch: 227 loss: tensor(0.4425)
# epoch: 228 loss: tensor(0.4434)
# epoch: 229 loss: tensor(0.4424)
# epoch: 230 loss: tensor(0.4414)
# epoch: 231 loss: tensor(0.4454)
# epoch: 232 loss: tensor(0.4414)
# epoch: 233 loss: tensor(0.4439)
# epoch: 234 loss: tensor(0.4440)
# epoch: 235 loss: tensor(0.4435)
# epoch: 236 loss: tensor(0.4510)
# epoch: 237 loss: tensor(0.4456)
# epoch: 238 loss: tensor(0.4427)
# epoch: 239 loss: tensor(0.4413)
# epoch: 240 loss: tensor(0.4420)
# epoch: 241 loss: tensor(0.4442)
# epoch: 242 loss: tensor(0.4494)
# epoch: 243 loss: tensor(0.4418)
# epoch: 244 loss: tensor(0.4418)
# epoch: 245 loss: tensor(0.4427)
# epoch: 246 loss: tensor(0.4414)
# epoch: 247 loss: tensor(0.4408)
# epoch: 248 loss: tensor(0.4422)
# epoch: 249 loss: tensor(0.4449)
# epoch: 250 loss: tensor(0.4429)
# epoch: 251 loss: tensor(0.4433)
# epoch: 252 loss: tensor(0.4441)
# epoch: 253 loss: tensor(0.4461)
# epoch: 254 loss: tensor(0.4385)
# epoch: 255 loss: tensor(0.4419)
# epoch: 256 loss: tensor(0.4452)
# epoch: 257 loss: tensor(0.4463)
# epoch: 258 loss: tensor(0.4395)
# epoch: 259 loss: tensor(0.4441)
# epoch: 260 loss: tensor(0.4436)
# epoch: 261 loss: tensor(0.4391)
# epoch: 262 loss: tensor(0.4408)
# epoch: 263 loss: tensor(0.4415)
# epoch: 264 loss: tensor(0.4408)
# epoch: 265 loss: tensor(0.4425)
# epoch: 266 loss: tensor(0.4423)
# epoch: 267 loss: tensor(0.4408)
# epoch: 268 loss: tensor(0.4403)
# epoch: 269 loss: tensor(0.4403)
# epoch: 270 loss: tensor(0.4396)
# epoch: 271 loss: tensor(0.4403)
# epoch: 272 loss: tensor(0.4424)
# epoch: 273 loss: tensor(0.4420)
# epoch: 274 loss: tensor(0.4389)
# epoch: 275 loss: tensor(0.4397)
# epoch: 276 loss: tensor(0.4402)
# epoch: 277 loss: tensor(0.4419)
# epoch: 278 loss: tensor(0.4408)
# epoch: 279 loss: tensor(0.4368)
# epoch: 280 loss: tensor(0.4373)
# epoch: 281 loss: tensor(0.4401)
# epoch: 282 loss: tensor(0.4424)
# epoch: 283 loss: tensor(0.4393)
# epoch: 284 loss: tensor(0.4488)
# epoch: 285 loss: tensor(0.4452)
# epoch: 286 loss: tensor(0.4412)
# epoch: 287 loss: tensor(0.4378)
# epoch: 288 loss: tensor(0.4423)
# epoch: 289 loss: tensor(0.4419)
# epoch: 290 loss: tensor(0.4396)
# epoch: 291 loss: tensor(0.4372)
# epoch: 292 loss: tensor(0.4373)
# epoch: 293 loss: tensor(0.4382)
# epoch: 294 loss: tensor(0.4390)
# epoch: 295 loss: tensor(0.4381)
# epoch: 296 loss: tensor(0.4366)
# epoch: 297 loss: tensor(0.4379)
# epoch: 298 loss: tensor(0.4426)
# epoch: 299 loss: tensor(0.4444)
# epoch: 300 loss: tensor(0.4408)

# %%
def score(data, targ):
  acc = 0
  for i in range(len(data)):
    with torch.no_grad():
      input = Variable(data[i]).unsqueeze(0)
      target = targ[i]
    
      # get output from nn
      output = ann2(input)

      if list(target).index(1) == list(output[0]).index(max(list(output[0]))):
        acc += 1

  return(acc/len(data))

print(score(test_x, test_y))
# Out:
# 0.21621621621621623
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app

# %% [markdown]
# I wasn't able to create a better model, but at this point, I have three decent models. It might be a good idea to combine the two models. I test this theory below.

# %%
forest = RandomForestClassifier(max_depth=4, n_estimators=50, random_state=0)
forest = forest.fit(x, y)

def score(data, targ):
  acc = 0
  for i in range(len(data)):
    with torch.no_grad():
      inp = Variable(data[i]).unsqueeze(0)
      target = targ[i]
    
      # get output from nn
      output1 = ann(inp)
      output2 = ann2(inp)
      output3 = forest.predict(inp[0].numpy().reshape(1, -1))
    
      output1 = list(output1[0]).index(max(list(output1[0])))
      output2 = list(output2[0]).index(max(list(output2[0])))
      output3 = output3[0]
      print(output3)

      if output1 == output2:
        pred = output1
      if output1 == output3:
        pred = output1
      if output2 == output3:
        pred = output2
      
      if pred == list(target).index(1):
        acc += 1

  return(acc/len(data))

print(score(test_x, test_y))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# 1
# 1
# 2
# 0
# 0
# 2
# 0
# 2
# 0
# 1
# 2
# 0
# 1
# 0
# 1
# 1
# 0
# 2
# 0
# 1
# 2
# 0
# 2
# 1
# 1
# 2
# 0
# 1
# 1
# 1
# 2
# 0
# 1
# 2
# 1
# 2
# 1
# 0.5675675675675675
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app

# %% [markdown]
# This ensemble of classifiers seems to perform better than any other model. I will use this for the test set.

# %%
color = pd.get_dummies(test_df['color'], prefix='color')

test_df = test_df.drop(['color'], axis=1)
test_df = pd.concat([test_df, color], axis=1)

# %%
test = test_df.to_numpy()
test_tens = torch.FloatTensor(test)

# %%
def predict(data):
  preds = []
  for i in range(len(data)):
    with torch.no_grad():
      inp = Variable(data[i]).unsqueeze(0)
    
      # get output from nn
      output1 = ann(inp)
      output2 = ann2(inp)
      output3 = forest.predict(inp[0].numpy().reshape(1, -1))
    
      output1 = list(output1[0]).index(max(list(output1[0])))
      output2 = list(output2[0]).index(max(list(output2[0])))
      output3 = output3[0]

      if output1 == output2:
        pred = output1
      if output1 == output3:
        pred = output1
      if output2 == output3:
        pred = output2
        
      if output3 == 0:
        pred = 'Ghost'
      if output3 == 1:
        pred = 'Ghoul'
      if output3 == 2:
        pred = 'Goblin'
      preds.append(pred)

  return preds

preds = predict(test_tens)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# ...
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app

# %%
sample = pd.read_csv('../input/ghouls-goblins-and-ghosts-boo/sample_submission.csv.zip', compression='zip')
pd.DataFrame({'id': sample['id'], 'type': preds}).to_csv('submission.csv', index=False)

# %%
sample.head(-10)
# Out:
#       id   type
# 0      3  Ghost
# 1      6  Ghost
# 2      9  Ghost
# 3     10  Ghost
# 4     13  Ghost
# ..   ...    ...
# 514  880  Ghost
# 515  881  Ghost
# 516  882  Ghost
# 517  883  Ghost
# 518  884  Ghost
#
# [519 rows x 2 columns]
